# %% [markdown]
# ## ❌ DO NOT EDIT - MAKE A COPY
# # Q1: Alphabet Slices
# * Store the first ten letters of the alphabet in a list.
# * Use a slice to print out the first three letters of the alphabet.
# * Use a slice to print out any three letters from the middle of your list.

# %%
# Solve Alphabet slices here. 
## Extra Credit:  Do this without 'hard coding' the alpahbet.

alphabet = []

for i in range(10):
    alphabet.append(chr (97+i))

print(alphabet[0:3])

print(alphabet[5:8])
# Out:
# ['a', 'b', 'c']
# ['f', 'g', 'h']

# %% [markdown]
# # Q2:  Covert all the rapper names to title case and save them into a new different list.
# Example: **lil wayne** becomes **Lil Wayne**

# %%
# Solve rapper names here
rappers = ['lil wayne', 'nicki minaj', 'drake']


titledRappers = [i.title() for i in rappers]

print(titledRappers)
# Out:
# ['Lil Wayne', 'Nicki Minaj', 'Drake']

# %% [markdown]
# # Q3: Write a function that takes a number and returns:
# * True if the input number is even.
# * False if the input number is odd.

# %%
# Solve problem here

def even_odd(n):
    if n%2 == 0:
      return True
    else:
      return False
   

print(even_odd(2))
print(even_odd(3))
# Out:
# True
# False

# %% [markdown]
# # Q4: Find the sum and the average of this list of numbers.
#
# Try doing this using a loop.  Then try doing this without using a loop.

# %%
# Solve problem here:

my_list = [1, 5, 10, 55, 88, 44, 42, 50, 20, 38]

#using a loop
list_sum = 0

for i in my_list:
    list_sum += i

list_avg = list_sum / len(my_list)


# Without loops
list_sum2 = sum(my_list)
list_avg2 = list_sum2 / len(my_list)


# Keep this as your last line in this cell.
print("WITH LOOPS: List Sum =", list_sum," ,List Average= ", list_avg)
print("WITHOT LOOPS: List Sum =", list_sum2, " ,List Average=", list_avg2)
# Out:
# WITH LOOPS: List Sum = 353  ,List Average=  35.3
# WITHOT LOOPS: List Sum = 353  ,List Average= 35.3

# %% [markdown]
# # Q5:
# ## Write a function that takes a list and returns a new list that has all the duplicates removed.
#
# Example input and expected output:
# - input = `["Michele", "Robin", "Sara", "Michele"]`
# - expected output = `['Michele', 'Robin', 'Sara']`

# %%
# Solve problem here:

names = ["Michele", "Robin", "Sara", "Michele"]

def removeDuplicates(list):
    newList = []

    for item in list:
        if item not in newList:
            newList.append(item)

    return newList

print(removeDuplicates(names))
# Out:
# ['Michele', 'Robin', 'Sara']

# %% [markdown]
# # Q6: Write a function that takes a list of numbers
# (for example, `a = [5, 10, 15, 20, 25]`) and returns a new list of only the first and last elements of the given list.
#
# Example input and expected output:
# - input = `[5, 10, 15, 20, 25]`
# - expected output = `[5, 25]`

# %%
# Solve problem here:
input_list = [5, 10, 99, 20, 25]

def FirstAndLast(list):
    newList = []
    newList.append(list[0])
    newList.append(list[-1])

    return newList

print(FirstAndLast(input_list))
# Out:
# [5, 25]

# %% [markdown]
# # Q7:
# ## Implement a function that takes as input three variables, and returns the largest of the three.
# ### Try doing this without using the `max()` function!
#
# _**Note:** all three input numbers will always be different, no need to account for a tie._
#
# Example input and expected output:
# - input: `your_function(1, 5, 10)`
# - expected output:  `10`

# %%
# Solve Problem here:


def my_max(a, b, c):
    if a > b:
        if a > c:
            return a
        else:
            return c
    elif b > c:
        return b
    else:
        return c

print(my_max(1,5,10))
# Out:
# 10

# %%
# Test to see if your function works properly.
my_max(1, 5, 10)
# Out:
# 10

# %% [markdown]
# # Q8: Write a function that takes a number as input and returns the following:
# * If the input is divisible by three, return `'fizz'`
# * If the input is divisible by five, return `'buzz'`
# * If the input is divisible by three and by five, return `'fizzbuzz'`
# * If the input is not divisible by three or five, return `None`.

# %%
# Solve Problem fizzbuzz here:
def FizzBuzz(n):
    if n%3 == 0:
        if n%5 ==0:
            return 'fizzbuzz'
        else:
            return 'fizz'

    elif n%5 ==0:
        return 'buzz'

    else:
        return 'None'

print(FizzBuzz(15))
print(FizzBuzz(9))
print(FizzBuzz(10))
print(FizzBuzz(4))
# Out:
# fizzbuzz
# fizz
# buzz
# None
